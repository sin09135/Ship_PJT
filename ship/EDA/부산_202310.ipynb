# %%
import pandas as pd

df = pd.read_csv('EDA/부산_202310.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9501 entries, 0 to 9500
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   순번                 9501 non-null   int64
#  1   호출부호               9501 non-null   object
#  2   입항횟수               9501 non-null   int64
#  3   입항횟수.1             9501 non-null   int64
#  4   입항횟수.2             9501 non-null   int64
#  5   신고톤수               9501 non-null   object
#  6   선박명                9501 non-null   object
#  7   선사/대리점             9501 non-null   object
#  8   선사/대리점.1           9501 non-null   object
#  9   신청시설               9501 non-null   object
#  10  신청시설.1             9501 non-null   object
#  11  신청시설.2             9501 non-null   object
#  12  신청일시(FROM ~ TO)    9501 non-null   object
#  13  신청일시(FROM ~ TO).1  9501 non-null   object
#  14  지정시설               7486 non-null   object
#  15  지정시설.1             7486 non-null   object
# ...

# %%
ddf = df[df['사용목적명'] == '접안대기']

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1774 entries, 0 to 9495
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   순번                 1774 non-null   int64
#  1   호출부호               1774 non-null   object
#  2   입항횟수               1774 non-null   int64
#  3   입항횟수.1             1774 non-null   int64
#  4   입항횟수.2             1774 non-null   int64
#  5   신고톤수               1774 non-null   object
#  6   선박명                1774 non-null   object
#  7   선사/대리점             1774 non-null   object
#  8   선사/대리점.1           1774 non-null   object
#  9   신청시설               1774 non-null   object
#  10  신청시설.1             1774 non-null   object
#  11  신청시설.2             1774 non-null   object
#  12  신청일시(FROM ~ TO)    1774 non-null   object
#  13  신청일시(FROM ~ TO).1  1774 non-null   object
#  14  지정시설               1254 non-null   object
#  15  지정시설.1             1254 non-null   object
# ...

# %%
ddf.to_csv('부산_접안대기_202310.csv', index = False, encoding = 'utf-8-sig')

# %%
# Out:
#         순번    호출부호  입항횟수  입항횟수.1  입항횟수.2    신고톤수              선박명   선사/대리점  \
# 0        1  9V8011  2023      42       1   7.464  PACIFIC TIANJIN  ICZ0830
# 9       10   DSEK8  2023      56       1   3.994       SUNNY PALM  KMS8832
# 11      12  9V7921  2023      27       1   9.962   PACIFIC GENEVA  OSL0038
# 21      22   DSQX4  2023       2       1   4.562            LEPUS  BSC2203
# 29      30   DSFU2  2023     115       3  21.688    PANSTAR DREAM  KMC0725
# ...    ...     ...   ...     ...     ...     ...              ...      ...
# 9491  9492  835523  2023       5      46      74             동진1호  BSB2508
# 9492  9493  835523  2023       5      47      74             동진1호  BSB2508
# 9493  9494  835523  2023       5      48      74             동진1호  BSB2508
# 9494  9495  835523  2023       5      49      74             동진1호  BSB2508
# 9495  9496  835523  2023       5      50      74             동진1호  BSB2508
#
# ...
