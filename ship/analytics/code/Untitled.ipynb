# %%
import pandas as pd

# %%
import pandas as pd
PATH  = '../data/'

df = pd.read_csv(PATH + '액체_모델용.csv')

# %%
df
# Out:
#                   Datetime  ETA_Year  ETA_Month  ETA_Day  ETA_Hour    호출부호  \
# 0      2020-01-01 01:00:00      2020          1        1         1   88238
# 1      2020-01-01 03:00:00      2020          1        1         3   DSRB9
# 2      2020-01-01 04:00:00      2020          1        1         4    D7SC
# 3      2020-01-01 05:00:00      2020          1        1         5  130095
# 4      2020-01-01 05:00:00      2020          1        1         5  160014
# ...                    ...       ...        ...      ...       ...     ...
# 50996  2022-12-31 09:00:00      2022         12       31         9  130037
# 50997  2022-12-31 09:00:00      2022         12       31         9  130064
# 50998  2022-12-31 10:00:00      2022         12       31        10    HOXG
# 50999  2022-12-31 15:00:00      2022         12       31        15  200013
# 51000  2022-12-31 17:00:00      2022         12       31        17   66597
#
# ...
